# %%
import pandas as pd
df_hotel = pd.read_csv("dim_hotels.csv")
df_hotel.head(2)
# Out:
#    property_id  property_name category    city
# 0        16558   Atliq Grands   Luxury   Delhi
# 1        16559  Atliq Exotica   Luxury  Mumbai

# %%
df_date = pd.read_csv("dim_date.csv")
df_date.head(2)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday

# %%
df_rooms = pd.read_csv("dim_rooms.csv")
df_rooms.head(2)
# Out:
#   room_id room_class
# 0     RT1   Standard
# 1     RT2      Elite

# %%
df_aggregated_bookings = pd.read_csv("fact_aggregated_bookings.csv")
df_aggregated_bookings.head(2)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0

# %%
df_booking = pd.read_csv("fact_bookings.csv")
df_booking.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640

# %%
df_new_aug = pd.read_csv("new_data_august.csv")
df_new_aug.head(2)
# Out:
#    property_id  property_name category       city room_category room_class  \
# 0        16559  Atliq Exotica   Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay   Luxury  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
#
#     occ%
# 0  100.0
# 1   70.0

# %%
df_booking.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
df_booking.shape
# Out:
# (134590, 12)

# %%
df_booking.room_category.unique()
# Out:
# <StringArray>
# ['RT1', 'RT2', 'RT3', 'RT4']
# Length: 4, dtype: str

# %%
df_booking.booking_platform.unique()
# Out:
# <StringArray>
# [ 'direct online',         'others',        'logtrip',       'tripster',
#    'makeyourtrip',        'journey', 'direct offline']
# Length: 7, dtype: str

# %%
df_booking.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_booking.booking_platform.value_counts().plot(kind = "barh", )
# Out:
# <Axes: ylabel='booking_platform'>

# %%
df_booking.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_hotel.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_hotel.category.value_counts().sort_values()
# Out:
# category
# Business     9
# Luxury      16
# Name: count, dtype: int64

# %%
df_hotel.shape
# Out:
# (25, 4)

# %%
import matplotlib.pyplot as plt
df_hotel.city.value_counts().sort_values().plot(kind="bar")

plt.xticks(rotation=45)
plt.show()

# %%
**Exercise-2. Find out total bookings per property_id**
# Out:
#   Cell In[20], line 1
#     **Exercise-2. Find out total bookings per property_id**
#     ^
# SyntaxError: invalid syntax

# %%
df_aggregated_bookings.head(2)

# %%
df_aggregated_bookings.property_id.unique()

# %%
 ** Exercise-2. Find out total bookings per property_id **

# %%
df_aggregated_bookings.groupby("property_id") ["successful_bookings"] .sum()

# %%
**Exercise-3. Find out days on which bookings are greater than capacity**

# %%
df_aggregated_bookings[df_aggregated_bookings.successful_bookings>df_aggregated_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
**Exercise-4. Find out properties that have highest capacity**
# Out:
#   Cell In[22], line 1
#     **Exercise-4. Find out properties that have highest capacity**
#     ^
# SyntaxError: invalid syntax

# %%
df_aggregated_bookings.capacity.max()
# Out:
# np.float64(50.0)

# %%
df_aggregated_bookings[df_aggregated_bookings.capacity == df_aggregated_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# # ==> 2 DATA CLEANING

# %%
df_booking.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_booking[df_booking.no_guests <= 0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_booking.shape
# Out:
# (134590, 12)

# %%
df_booking = df_booking[df_booking.no_guests > 0]
df_booking
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_booking.shape
# Out:
# (134578, 12)

# %%
df_booking[df_booking.no_guests <= 0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_booking.revenue_generated.min() , df_booking.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
avg, std = df_booking.revenue_generated.mean(), df_booking.revenue_generated.std()

# %%
avg, std
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# np.float64(-263742.4278567056)

# %%
df_booking[df_booking.revenue_generated > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_booking = df_booking[df_booking.revenue_generated < higher_limit]
df_booking.shape
# Out:
# (134573, 12)

# %%
df_booking.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = df_booking.revenue_realized.mean() + 3*df_booking.revenue_realized.std()
higher_limit
# Out:
# np.float64(33479.358661845814)

# %%
df_booking[df_booking.revenue_realized > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_booking[df_booking.room_category == "RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
23439 + 3* 9048
# Out:
# 50583

# %%
df_booking.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# **Exercise-1. In aggregate bookings find columns that have null values. Fill these null values with whatever you think is the appropriate subtitute (possible ways is to use mean or median)**

# %%
df_aggregated_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_aggregated_bookings.describe()
# Out:
#         property_id  successful_bookings     capacity
# count   9200.000000          9200.000000  9198.000000
# mean   18040.640000            14.655761    25.280496
# std     1099.818325             7.736170    11.442080
# min    16558.000000             1.000000     3.000000
# 25%    17558.000000             9.000000    18.000000
# 50%    17564.000000            14.000000    25.000000
# 75%    18563.000000            19.000000    34.000000
# max    19563.000000           123.000000    50.000000

# %%
df_aggregated_bookings[df_aggregated_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
df_aggregated_bookings["capacity"] = df_aggregated_bookings["capacity"].replace(
    "Nan",
    df_aggregated_bookings["capacity"].median()
)

# %%
df_aggregated_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               0
# dtype: int64

# %%
df_aggregated_bookings[df_aggregated_bookings.capacity == 25]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 8           17561      1-May-22           RT1                   22      25.0
# 14          17562      1-May-22           RT1                   12      25.0
# 15          17563      1-May-22           RT1                   21      25.0
# 58          17560      1-May-22           RT3                   19      25.0
# 59          18561      1-May-22           RT3                   23      25.0
# ...           ...           ...           ...                  ...       ...
# 9059        17560     30-Jul-22           RT3                   16      25.0
# 9060        18561     30-Jul-22           RT3                   19      25.0
# 9116        17563     31-Jul-22           RT1                   20      25.0
# 9159        18561     31-Jul-22           RT3                   19      25.0
# 9167        17560     31-Jul-22           RT3                   14      25.0
#
# [278 rows x 5 columns]

# %%
**Exercise-2. In aggregate bookings find out records that have successful_bookings value greater than capacity. Filter those records**

# %%
df_aggregated_bookings[df_aggregated_bookings.successful_bookings > df_aggregated_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_aggregated_bookings[df_aggregated_bookings.successful_bookings > df_aggregated_bookings.capacity].shape
# Out:
# (6, 5)

# %%
df_aggregated_bookings[df_aggregated_bookings.successful_bookings <= df_aggregated_bookings.capacity].shape
# Out:
# (9194, 5)

# %% [markdown]
# # ==> DATA TRANSFORMATION

# %%
df_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_aggregated_bookings["oct_pct"] = df_aggregated_bookings["successful_bookings"]/ df_aggregated_bookings["capacity"]
df_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#     oct_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 3  1.578947
# 4  0.947368

# %%
df_aggregated_bookings["oct_pct"] = df_aggregated_bookings["oct_pct"].apply( lambda x: round(x*100, 2)) 
df_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    oct_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89
# 4    94.74

# %% [markdown]
# ***
# ### ==> 4. Insights Generation
# ***

# %% [markdown]
# # **1. What is an average occupancy rate in each of the room categories?**

# %%
df_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    oct_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89
# 4    94.74

# %%
df_aggregated_bookings.groupby("room_category")["oct_pct"].mean().round(2)
# Out:
# room_category
# RT1    58.23
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: oct_pct, dtype: float64

# %%
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_aggregated_bookings, df_rooms, left_on = "room_category", right_on = "room_id")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    oct_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3   157.89     RT1   Standard
# 4    94.74     RT1   Standard

# %%
df.groupby("room_class")["oct_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.23
# Name: oct_pct, dtype: float64

# %%
df.drop("room_id", axis = 1, inplace = True)
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    oct_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard

# %% [markdown]
# # 2. Print avg occupancy rate per city?

# %%
df_hotel.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df.head(2)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
#
#    oct_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard

# %%
avg_occ_per_city = pd.merge(df, df_hotel, on = "property_id")
avg_occ_per_city.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    oct_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore
# 3   157.89   Standard   Atliq Grands    Luxury     Mumbai

# %%
avg_occ_per_city.groupby("city")["oct_pct"].mean().round(2).plot(kind = "bar")
plt.title("Average Occupancy Rate by City")
plt.show()

# %% [markdown]
# # **3. When was the occupancy better? Weekday or Weekend?**

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
avg_occ_per_city.head(2)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
#
#    oct_pct room_class  property_name category       city
# 0    83.33   Standard  Atliq Exotica   Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay   Luxury  Bangalore

# %%
avg_per_date = pd.merge(df_date, avg_occ_per_city, left_on = "date", right_on = "check_in_date")
avg_per_date
# Out:
#            date  mmm yy week no  day_type  property_id check_in_date  \
# 0     10-May-22  May 22    W 20  weekeday        19563     10-May-22
# 1     10-May-22  May 22    W 20  weekeday        18560     10-May-22
# 2     10-May-22  May 22    W 20  weekeday        19562     10-May-22
# 3     10-May-22  May 22    W 20  weekeday        19563     10-May-22
# 4     10-May-22  May 22    W 20  weekeday        17558     10-May-22
# ...         ...     ...     ...       ...          ...           ...
# 6495  31-Jul-22  Jul 22    W 32   weekend        16563     31-Jul-22
# 6496  31-Jul-22  Jul 22    W 32   weekend        16559     31-Jul-22
# 6497  31-Jul-22  Jul 22    W 32   weekend        17558     31-Jul-22
# 6498  31-Jul-22  Jul 22    W 32   weekend        19563     31-Jul-22
# 6499  31-Jul-22  Jul 22    W 32   weekend        17561     31-Jul-22
#
#      room_category  successful_bookings  capacity  oct_pct    room_class  \
# ...

# %%
avg_per_date.groupby("day_type")["oct_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: oct_pct, dtype: float64

# %%
**4: In the month of June, what is the occupancy for different cities**

# %%
avg_per_date.groupby("mmm yy")["oct_pct"].mean().round(2)
# Out:
# mmm yy
# Jul 22    55.77
# Jun 22    58.79
# May 22    57.07
# Name: oct_pct, dtype: float64

# %%
df_june = avg_per_date[avg_per_date["mmm yy"] == "Jun 22"]
df_june.head(2)
# Out:
#            date  mmm yy week no  day_type  property_id check_in_date  \
# 2200  10-Jun-22  Jun 22    W 24  weekeday        16559     10-Jun-22
# 2201  10-Jun-22  Jun 22    W 24  weekeday        19562     10-Jun-22
#
#      room_category  successful_bookings  capacity  oct_pct room_class  \
# 2200           RT1                   20      30.0    66.67   Standard
# 2201           RT1                   19      30.0    63.33   Standard
#
#       property_name category       city
# 2200  Atliq Exotica   Luxury     Mumbai
# 2201      Atliq Bay   Luxury  Bangalore

# %%
df_hotel.head(2)
# Out:
#    property_id  property_name category    city
# 0        16558   Atliq Grands   Luxury   Delhi
# 1        16559  Atliq Exotica   Luxury  Mumbai

# %%
df_ = pd.merge(df_june, df_hotel, on = "property_id")
df_.head()
# Out:
#         date  mmm yy week no  day_type  property_id check_in_date  \
# 0  10-Jun-22  Jun 22    W 24  weekeday        16559     10-Jun-22
# 1  10-Jun-22  Jun 22    W 24  weekeday        19562     10-Jun-22
# 2  10-Jun-22  Jun 22    W 24  weekeday        19563     10-Jun-22
# 3  10-Jun-22  Jun 22    W 24  weekeday        17558     10-Jun-22
# 4  10-Jun-22  Jun 22    W 24  weekeday        16558     10-Jun-22
#
#   room_category  successful_bookings  capacity  oct_pct room_class  \
# 0           RT1                   20      30.0    66.67   Standard
# 1           RT1                   19      30.0    63.33   Standard
# 2           RT1                   17      30.0    56.67   Standard
# 3           RT1                    9      19.0    47.37   Standard
# 4           RT1                   11      19.0    57.89   Standard
#
#   property_name_x category_x     city_x property_name_y category_y     city_y
# 0   Atliq Exotica     Luxury     Mumbai   Atliq Exotica     Luxury     Mumbai
# ...

# %%
df_.groupby("city_y")["oct_pct"].mean().round(2).sort_values(ascending=False).plot(kind="bar")

plt.title("Average Occupancy Rate by City – June 2022")
plt.xlabel("City")
plt.ylabel("Average Occupancy (%)")
plt.xticks(rotation=45)

plt.show()

# %%
df_new_aug.head(2)
# Out:
#    property_id  property_name category       city room_category room_class  \
# 0        16559  Atliq Exotica   Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay   Luxury  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
#
#     occ%
# 0  100.0
# 1   70.0

# %%
avg_per_date.head(2)
# Out:
#         date  mmm yy week no  day_type  property_id check_in_date  \
# 0  10-May-22  May 22    W 20  weekeday        19563     10-May-22
# 1  10-May-22  May 22    W 20  weekeday        18560     10-May-22
#
#   room_category  successful_bookings  capacity  oct_pct room_class  \
# 0           RT3                   15      29.0    51.72    Premium
# 1           RT1                   19      30.0    63.33   Standard
#
#   property_name  category       city
# 0  Atliq Palace  Business  Bangalore
# 1    Atliq City  Business  Hyderabad

# %%
df_new = pd.concat([df, df_new_aug], ignore_index = True, axis = 0)
df_new.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
# 9200        16559     01-Aug-22           RT1                   30      30.0
# 9201        19562     01-Aug-22           RT1                   21      30.0
# 9202        19563     01-Aug-22           RT1                   23      30.0
# 9203        19558     01-Aug-22           RT1                   30      40.0
# 9204        19560     01-Aug-22           RT1                   20      26.0
# 9205        17561     01-Aug-22           RT1                   18      26.0
# 9206        17564     01-Aug-22           RT1                   10      16.0
#
#       oct_pct    room_class  property_name  category       city  mmm yy  \
# ...

# %% [markdown]
# # print revenue_realized per city

# %%
df_booking.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920

# %%
df_hotel.head(2)
# Out:
#    property_id  property_name category    city
# 0        16558   Atliq Grands   Luxury   Delhi
# 1        16559  Atliq Exotica   Luxury  Mumbai

# %%
rev_realized = pd.merge(df_booking,df_hotel, on ="property_id" )
rev_realized.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
rev_realized.groupby("city")["revenue_realized"].sum().sort_values(ascending=False)
# Out:
# city
# Mumbai       668569251
# Bangalore    420383550
# Hyderabad    325179310
# Delhi        294404488
# Name: revenue_realized, dtype: int64

# %% [markdown]
# # Print month by month revenue

# %%
df_date.head(2)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday

# %%
df_date["date"] = pd.to_datetime(
    df_dates["date"]
)

# %%
df_date.head(2)
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday

# %%
rev_realized["check_in_date"] = pd.to_datetime(
    rev_realized["check_in_date"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 rev_realized["check_in_date"] = pd.to_datetime(
#       2     rev_realized["check_in_date"])
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\tools\datetimes.py:1036, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1034             result = arg.tz_localize("utc")
#    1035 elif isinstance(arg, ABCSeries):
# -> 1036     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1037     if not cache_array.empty:
#    1038         result = arg.map(cache_array)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# ...

# %%
rev_realized.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  str
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  str
#  3   check_in_date      134573 non-null  str
#  4   checkout_date      134573 non-null  str
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  str
#  7   booking_platform   134573 non-null  str
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  str
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  str
#  13  category           134573 non-null  str
#  14  city               134573 non-null  str
# dtypes: float64(2), int64(3), str(10)
# memory usage: 15.4 MB

# %%
rev_realized["check_in_date"] = pd.to_datetime(
    rev_realized["check_in_date"],
    format="mixed"
)

# %%
rev_realized.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-01-05      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-01-05      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-01-05      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
month_by_month_rev = pd.merge(rev_realized, df_date, left_on = "check_in_date", right_on = "date")
month_by_month_rev.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# 2              10010             10010  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no  day_type
# 0 2022-05-05  May 22    W 19  weekeday
# ...

# %%
month_by_month_rev.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    389940912
# Jun 22    377191229
# May 22    408375641
# Name: revenue_realized, dtype: int64
